# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

# %%
n_nodes_hl1 = 500
n_nodes_hl2 = 500
n_nodes_hl3 = 500
n_classes = 10
batch_size = 100

# Use keras.Input instead of placeholders
x = tf.keras.Input( shape=(28*28), dtype=tf.dtypes.float32)
y = tf.keras.Input(shape = (), dtype=tf.dtypes.float32)

# %%
def neural_network_model(data):
    hidden_1_layer = {'weights':tf.Variable(tf.random.normal([784, n_nodes_hl1])),
                      'biases':tf.Variable(tf.random.normal([n_nodes_hl1]))}

    hidden_2_layer = {'weights':tf.Variable(tf.random.normal([n_nodes_hl1, n_nodes_hl2])),
                      'biases':tf.Variable(tf.random.normal([n_nodes_hl2]))}

    hidden_3_layer = {'weights':tf.Variable(tf.random.normal([n_nodes_hl2, n_nodes_hl3])),
                      'biases':tf.Variable(tf.random.normal([n_nodes_hl3]))}

    output_layer = {'weights':tf.Variable(tf.random.normal([n_nodes_hl3, n_classes])),
                    'biases':tf.Variable(tf.random.normal([n_classes]))}
    
    # (input_data * weights) + biases
    
    l1 = tf.add(tf.matmul(data,hidden_1_layer['weights']), hidden_1_layer['biases'])
    l1 = tf.nn.relu(l1)  # activation func

    l2 = tf.add(tf.matmul(l1,hidden_2_layer['weights']), hidden_2_layer['biases'])
    l2 = tf.nn.relu(l2)  # activation func

    l3 = tf.add(tf.matmul(l2,hidden_3_layer['weights']), hidden_3_layer['biases'])
    l3 = tf.nn.relu(l3)  # activation func

    output = tf.matmul(l3,output_layer['weights']) + output_layer['biases']

    return output

# %%
def train_neural_network(x):
    prediction = neural_network_model(x)
    cost = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=prediction, labels=y) )
    optimizer = tf.optimizers.Adam().minimize(cost)
    hm_epochs = 10
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())

        for epoch in range(hm_epochs):
            epoch_loss = 0
            for _ in range(int(mnist.train.num_examples/batch_size)):
                epoch_x, epoch_y = mnist.train.next_batch(batch_size)
                _, c = sess.run([optimizer, cost], feed_dict={x: epoch_x, y: epoch_y})
                epoch_loss += c
            print('Epoch', epoch, 'completed out of',hm_epochs,'loss:',epoch_loss)

        correct = tf.equal(tf.argmax(prediction, 1), tf.argmax(y, 1))

        accuracy = tf.reduce_mean(tf.cast(correct, 'float'))
        print('Accuracy:',accuracy.eval({x:mnist.test.images, y:mnist.test.labels}))

train_neural_network(x)
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_40), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(784, 500) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.math.add_30), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(500,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_41), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(500, 500) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.math.add_31), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(500,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_42), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(500, 500) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.math.add_32), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(500,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_43), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(500, 10) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.__operators__.add_10), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(10,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8792/2819308597.py in <module>
#      20         print('Accuracy:',accuracy.eval({x:mnist.test.images, y:mnist.test.labels}))
#      21
# ---> 22 train_neural_network(x)
#
# ~\AppData\Local\Temp/ipykernel_8792/2819308597.py in train_neural_network(x)
#       2     prediction = neural_network_model(x)
#       3     cost = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=prediction, labels=y) )
# ----> 4     optimizer = tf.optimizers.Adam().minimize(cost)
#       5     hm_epochs = 10
#       6     with tf.Session() as sess:
#
# TypeError: minimize() missing 1 required positional argument: 'var_list'

# %%
def neural_network_model(data):
    hidden_1_layer = {'weights':tf.Variable(tf.random.normal([784, n_nodes_hl1])),
                      'biases':tf.Variable(tf.random.normal([n_nodes_hl1]))}

    hidden_2_layer = {'weights': tf.Variable(tf.random.normal([n_nodes_hl1, n_nodes_hl2])),
                      'biases': tf.Variable(tf.random.normal([n_nodes_hl2]))}

    hidden_3_layer = {'weights': tf.Variable(tf.random.normal([n_nodes_hl2, n_nodes_hl3])),
                      'biases': tf.Variable(tf.random.normal([n_nodes_hl3]))}

    output_layer = {'weights': tf.Variable(tf.random.normal([n_nodes_hl3, n_classes])),
                      'biases': tf.Variable(tf.random.normal([n_classes]))}

    l1 = tf.add(tf.matmul(data, hidden_1_layer['weights']), hidden_1_layer['biases'])
    l1 = tf.nn.relu(l1)

    l2 = tf.add(tf.matmul(l1, hidden_2_layer['weights']), hidden_2_layer['biases'])
    l2 = tf.nn.relu(l2)

    l3 = tf.add(tf.matmul(l2, hidden_3_layer['weights']), hidden_3_layer['biases'])
    l3 = tf.nn.relu(l3)

    output = tf.matmul(l3, output_layer['weights']) +  output_layer['biases']

    return(output)

def train_neural_network(x):
    prediction = neural_network_model(x)
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = prediction, labels = y))
    optimizer = tf.train.AdamOptimizer().minimize(cost)

    hm_epochs = 10

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())

        for epoch in range(hm_epochs):
            epoch_loss = 0
            for _ in range(int(mnist.train.num_examples/batch_size)):
                epoch_x, epoch_y = mnist.train.next_batch(batch_size)
                _, c = sess.run([optimizer, cost], feed_dict = {x:epoch_x, y:epoch_y})
                epoch_loss += c
            print('Epoch', epoch, 'completed out of', hm_epochs, 'loss:', epoch_loss)

        correct = tf.equal(tf.argmax(prediction, 1), tf.argmax(y,1))
        accuracy = tf.reduce_mean(tf.cast(correct, 'float'))
        print('Accuracy:', accuracy.eval({x:mnist.test.images, y:mnist.test.labels}))

train_neural_network(x)
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_44), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(784, 500) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.math.add_33), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(500,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_45), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(500, 500) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.math.add_34), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(500,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_46), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(500, 500) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.math.add_35), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(500,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.linalg.matmul_47), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(500, 10) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.__operators__.add_11), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=(10,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8792/15567310.py in <module>
#      47         print('Accuracy:', accuracy.eval({x:mnist.test.images, y:mnist.test.labels}))
#      48
# ---> 49 train_neural_network(x)
#
# ~\AppData\Local\Temp/ipykernel_8792/15567310.py in train_neural_network(x)
#      28     prediction = neural_network_model(x)
#      29     cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = prediction, labels = y))
# ---> 30     optimizer = tf.train.AdamOptimizer().minimize(cost)
#      31
#      32     hm_epochs = 10
#
# AttributeError: module 'tensorflow._api.v2.train' has no attribute 'AdamOptimizer'
