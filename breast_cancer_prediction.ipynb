# %%
import numpy as np
from sklearn import preprocessing, svm, model_selection, neighbors, svm
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv('breast-cancer-wisconsin.data')
df.replace('?', -99999, inplace = True)
#id has no implication to the algorithm, its an outlier
df.drop('id', axis=1, inplace = True)
df
# Out:
#      clump_thickness  unif_cell_size  unif_cell_shape  marg_adhesion  \
# 0                  5               1                1              1
# 1                  5               4                4              5
# 2                  3               1                1              1
# 3                  6               8                8              1
# 4                  4               1                1              3
# ..               ...             ...              ...            ...
# 694                3               1                1              1
# 695                2               1                1              1
# 696                5              10               10              3
# 697                4               8                6              4
# 698                4               8                8              5
#
#      single_epith_cell_size bare_nuclei  cland_chrom  norm_nucleoli  mitoses  \
# ...

# %%
X = np.array(df.drop('class',axis=1))
y = np.array(df['class'])

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size = 0.2)

clf = neighbors.KNeighborsClassifier()
clf.fit(X_train, y_train)

accuracy = clf.score(X_test, y_test)
print(accuracy)
# Out:
# 0.9714285714285714

# %%
example_measures = np.array([[4,2,4,5,3,2,4,2,1],[7,2,4,7,6,5,6,2,1],[3,2,4,1,3,6,4,3,1]])
example_measures = example_measures.reshape(len(example_measures), -1) # reshape for number of predictions
prediction = clf.predict(example_measures)
print(prediction)
# Out:
# [4 4 2]

# %%
X = np.array(df.drop('class',axis=1))
y = np.array(df['class'])

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size = 0.2)

clf = svm.SVC(kernel = "linear")
clf.fit(X_train, y_train)

accuracy = clf.score(X_test, y_test)
print(accuracy)

example_measures = np.array([[4,2,4,5,3,2,4,2,1],[7,2,4,7,6,5,6,2,1],[3,2,4,1,3,6,4,3,1]])
example_measures = example_measures.reshape(len(example_measures), -1) # reshape for number of predictions
prediction = clf.predict(example_measures)
print(prediction)
# Out:
# 0.9428571428571428
# [4 4 2]
